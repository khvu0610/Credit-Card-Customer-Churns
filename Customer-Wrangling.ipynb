# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Read Data

# %%
data1 = pd.read_csv("D:/Filechuan/adult.csv")
df1 = data1.copy()
df1
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90         ?   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66         ?  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
#               occupation   relationship   race     sex  capital.gain  \
# 0                      ?  Not-in-family  White  Female             0
# 1        Exec-managerial  Not-in-family  White  Female             0
# 2                      ?      Unmarried  Black  Female             0
# 3      Machine-op-inspct      Unmarried  White  Female             0
# 4         Prof-specialty      Own-child  White  Female             0
# ...                  ...            ...    ...     ...           ...
# 32556    Protective-serv  Not-in-family  White    Male             0
# 32557       Tech-support           Wife  White  Female             0
# 32558  Machine-op-inspct        Husband  White    Male             0
# 32559       Adm-clerical      Unmarried  White  Female             0
# 32560       Adm-clerical      Own-child  White    Male             0
#
#        capital.loss  hours.per.week native.country income
# 0              4356              40  United-States  <=50K
# 1              4356              18  United-States  <=50K
# 2              4356              40  United-States  <=50K
# 3              3900              40  United-States  <=50K
# 4              3900              40  United-States  <=50K
# ...             ...             ...            ...    ...
# 32556             0              40  United-States  <=50K
# 32557             0              38  United-States  <=50K
# 32558             0              40  United-States   >50K
# 32559             0              40  United-States  <=50K
# 32560             0              20  United-States  <=50K
#
# [32561 rows x 15 columns]

# %%
data2 = pd.read_csv("D:\Filechuan\dataset\Europe_supply_chain.csv")
df2 = data2.copy()
df2
# Out:
#        Unnamed: 0      Type  Days for shipping (real)  \
# 0            5777      CASH                         2
# 1           11912  TRANSFER                         5
# 2           12568     DEBIT                         3
# 3           13336     DEBIT                         5
# 4           15856      CASH                         0
# ...           ...       ...                       ...
# 50247      158912  TRANSFER                         6
# 50248      166549   PAYMENT                         3
# 50249      169251  TRANSFER                         6
# 50250      170046  TRANSFER                         6
# 50251      173439      CASH                         6
#
#        Days for shipment (scheduled)  Benefit per order  Sales per customer  \
# 0                                  1          41.060001          131.190002
# 1                                  4          19.559999          119.989998
# 2                                  4          37.849998          145.589996
# 3                                  4          65.070000          132.789993
# 4                                  0         -34.000000          135.990005
# ...                              ...                ...                 ...
# 50247                              4          16.299999          185.220001
# 50248                              4         -56.970001          181.440002
# 50249                              2          47.360001          164.429993
# 50250                              4          39.310001          151.199997
# 50251                              4          46.040001          164.429993
#
#          Delivery Status  Late_delivery_risk  Category Id  \
# 0          Late delivery                   1            3
# 1          Late delivery                   1            3
# 2       Advance shipping                   0            3
# 3          Late delivery                   1            3
# 4       Shipping on time                   0            3
# ...                  ...                 ...          ...
# 50247  Shipping canceled                   0           10
# 50248   Advance shipping                   0           10
# 50249      Late delivery                   1           10
# 50250      Late delivery                   1           10
# 50251      Late delivery                   1           10
#
#              Category Name  ... Order Zipcode Product Card Id  \
# 0      Baseball & Softball  ...           NaN              35
# 1      Baseball & Softball  ...           NaN              35
# 2      Baseball & Softball  ...           NaN              35
# 3      Baseball & Softball  ...           NaN              35
# 4      Baseball & Softball  ...           NaN              35
# ...                    ...  ...           ...             ...
# 50247    Strength Training  ...           NaN             216
# 50248    Strength Training  ...           NaN             216
# 50249    Strength Training  ...           NaN             216
# 50250    Strength Training  ...           NaN             216
# 50251    Strength Training  ...           NaN             216
#
#       Product Category Id Product Description  \
# 0                       3                 NaN
# 1                       3                 NaN
# 2                       3                 NaN
# 3                       3                 NaN
# 4                       3                 NaN
# ...                   ...                 ...
# 50247                  10                 NaN
# 50248                  10                 NaN
# 50249                  10                 NaN
# 50250                  10                 NaN
# 50251                  10                 NaN
#
#                                            Product Image  \
# 0      http://images.acmesports.sports/adidas+Brazuca...
# 1      http://images.acmesports.sports/adidas+Brazuca...
# 2      http://images.acmesports.sports/adidas+Brazuca...
# 3      http://images.acmesports.sports/adidas+Brazuca...
# 4      http://images.acmesports.sports/adidas+Brazuca...
# ...                                                  ...
# 50247  http://images.acmesports.sports/Yakima+DoubleD...
# 50248  http://images.acmesports.sports/Yakima+DoubleD...
# 50249  http://images.acmesports.sports/Yakima+DoubleD...
# 50250  http://images.acmesports.sports/Yakima+DoubleD...
# 50251  http://images.acmesports.sports/Yakima+DoubleD...
#
#                                         Product Name Product Price  \
# 0            adidas Brazuca 2014 Official Match Ball    159.990005
# 1            adidas Brazuca 2014 Official Match Ball    159.990005
# 2            adidas Brazuca 2014 Official Match Ball    159.990005
# 3            adidas Brazuca 2014 Official Match Ball    159.990005
# 4            adidas Brazuca 2014 Official Match Ball    159.990005
# ...                                              ...           ...
# 50247  Yakima DoubleDown Ace Hitch Mount 4-Bike Rack    189.000000
# 50248  Yakima DoubleDown Ace Hitch Mount 4-Bike Rack    189.000000
# 50249  Yakima DoubleDown Ace Hitch Mount 4-Bike Rack    189.000000
# 50250  Yakima DoubleDown Ace Hitch Mount 4-Bike Rack    189.000000
# 50251  Yakima DoubleDown Ace Hitch Mount 4-Bike Rack    189.000000
#
#       Product Status shipping date (DateOrders)   Shipping Mode
# 0                  0            8/17/2017 20:33     First Class
# 1                  0             8/14/2017 7:15  Standard Class
# 2                  0            8/30/2017 19:29  Standard Class
# 3                  0            8/25/2017 16:31  Standard Class
# 4                  0            12/7/2017 14:02        Same Day
# ...              ...                        ...             ...
# 50247              0            8/25/2017 16:20  Standard Class
# 50248              0            7/21/2017 21:17  Standard Class
# 50249              0             5/9/2017 15:06    Second Class
# 50250              0             4/8/2017 10:35  Standard Class
# 50251              0            8/14/2017 14:05  Standard Class
#
# [50252 rows x 54 columns]

# %%
data69 = pd.read_csv("D:\Filechuan\dataset\FleetJourney_EcomUStime.csv")
df69= data69.copy()
df69
# Out:
#       SENDERS_DATE RECEIVERS_DATE  TRANSPORTATION_DISTANCE_IN_KM ontime delay  \
# 0       18/05/2021     28/06/2021                          320.0     No   Yes
# 1       18/05/2021     28/06/2021                          103.0    Yes    No
# 2        11/4/2021     22/05/2021                          300.0    Yes    No
# 3       19/05/2021     29/06/2021                           61.0    Yes    No
# 4       18/05/2021     28/06/2021                          240.0    Yes    No
# ...            ...            ...                            ...    ...   ...
# 10000   19/04/2021     30/05/2021                           31.0     No   Yes
# 10001   20/04/2021     31/05/2021                           32.0     No   Yes
# 10002   21/04/2021       1/6/2021                           33.0     No   Yes
# 10003   22/04/2021       2/6/2021                           34.0     No   Yes
# 10004   23/04/2021       3/6/2021                           35.0     No   Yes
#
#       PREDICTED_DELIVERED_DATE  vehicle_no  \
# 0                   30/06/2021    KA590408
# 1                   30/06/2021  TN30BC5917
# 2                   24/05/2021  TN22AR2748
# 3                   29/06/2021  TN28AQ0781
# 4                   28/06/2021   TN68F1722
# ...                        ...         ...
# 10000                 1/6/2021   AP13X6670
# 10001                 2/6/2021   AP13X6671
# 10002                 3/6/2021   AP13X6672
# 10003                 4/6/2021   AP13X6673
# 10004                 5/6/2021   AP13X6674
#
#                                      vehicleType            Driver_Name  \
# 0                               Mahindra LCV 1MT                 RAMESH
# 1                               Mahindra LCV 1MT                 RAMESH
# 2                               Mahindra LCV 1MT                   GIRI
# 3                               Mahindra LCV 1MT                   RAVI
# 4                               Mahindra LCV 1MT                  TAMIL
# ...                                          ...                    ...
# 10000  41 FT Flat Bed Double-Axle 21MT - Trailer  thippaswamy nayak K T
# 10001  42 FT Flat Bed Double-Axle 21MT - Trailer  thippaswamy nayak K T
# 10002  43 FT Flat Bed Double-Axle 21MT - Trailer  thippaswamy nayak K T
# 10003  44 FT Flat Bed Double-Axle 21MT - Trailer  thippaswamy nayak K T
# 10004  45 FT Flat Bed Double-Axle 21MT - Trailer  thippaswamy nayak K T
#
#        Driver_MobileNo  customer_id First_name  supplierID  \
# 0           7082423013  72c00ba8bc7      James  VIJEXHOSR7
# 1           7082423014  b18a428ac77  Josephine  VJLEXSHE09
# 2           7082423015  2fdd0374a03        Art  GSTEXLAK1Q
# 3           7082423016  dc6358b12c3      Lenna  ARVEXNAM09
# 4           7082423017  c12e35b23ad    Donette  SRTEXKOR96
# ...                ...          ...        ...         ...
# 10000       9036703937  42c56b99070       Mary       59071
# 10001       9036703938  42c56b99071   Jennifer       59072
# 10002       9036703939  42c56b99072     Martha       59073
# 10003       9036703940  42c56b99073     Evelyn       59074
# 10004       9036703941  42c56b99074  Guinevere       59075
#
#             supplierNameCode             Material Shipped
# 0            VIJAY TRANSPORT        BRACKET / GRAB HANDLE
# 1               VJ LOGISTICS        ZB MODEL PLATE / 3143
# 2             G.S. TRANSPORT             LETTERING / FUSO
# 3          ARVINTH TRANSPORT     LU STRUT RA / RADIUS ROD
# 4              SR TRANSPORTS         WISHBONE / V ROD/HDT
# ...                      ...                          ...
# 10000  VINOD KAPOOR AND SONS  THRUST WASHER TSIDE CHAMFER
# 10001  VINOD KAPOOR AND SONS  THRUST WASHER TSIDE CHAMFER
# 10002  VINOD KAPOOR AND SONS  THRUST WASHER TSIDE CHAMFER
# 10003  VINOD KAPOOR AND SONS  THRUST WASHER TSIDE CHAMFER
# 10004  VINOD KAPOOR AND SONS  THRUST WASHER TSIDE CHAMFER
#
# [10005 rows x 15 columns]

# %%
data = pd.read_csv("D:\Filechuan\dataset\FleetJourneyorderinfor.csv")
df = data.copy()
df
# Out:
#            order_id order_id_date  vehicle_no  customer_id PLACE_OF_SENDERS  \
# 0       d792cb16214    15/05/2021    KA590408  72c00ba8bc7         New York
# 1       0d7a144bdd3    15/05/2021  TN30BC5917  b18a428ac77         San Jose
# 2       57da4fc703e      8/4/2021  TN22AR2748  2fdd0374a03       Birmingham
# 3       1b038114c75    16/05/2021  TN28AQ0781  dc6358b12c3         San Jose
# 4       bb4e55b4fd9    15/05/2021   TN68F1722  c12e35b23ad           Boston
# ...             ...           ...         ...          ...              ...
# 10015  57f78c2d0d17      2/5/2021   AP13X6686          NaN         San Jose
# 10016  57f78c2d0d18      3/5/2021   AP13X6687          NaN         San Jose
# 10017  57f78c2d0d19      4/5/2021   AP13X6688          NaN         San Jose
# 10018  57f78c2d0d20      5/5/2021   AP13X6689          NaN         San Jose
# 10019  57f78c2d0d21      6/5/2021   AP13X6690          NaN         San Jose
#
#       PLACE_OF_RECEIVERS 1 PLACE_OF_RECEIVERS 2 PLACE_OF_RECEIVERS 3  \
# 0      Chincoteague Island           Fort Wayne                 Mesa
# 1                   Exmore               Newark              Garland
# 2            Lawrenceville            Arlington           Scottsdale
# 3               Midlothian           Fort Wayne                Plano
# 4           Virginia Beach          Baton Rouge              Garland
# ...                    ...                  ...                  ...
# 10015                  NaN                  NaN              Garland
# 10016                  NaN                  NaN              Garland
# 10017         Johnson City                  NaN              Garland
# 10018         Johnson City            Charlotte                  NaN
# 10019         Johnson City            Charlotte              Garland
#
#        Unnamed: 8
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 10015         NaN
# 10016         NaN
# 10017         NaN
# 10018         NaN
# 10019         NaN
#
# [10020 rows x 9 columns]

# %% [markdown]
# Data Processing

# %%
df1.drop(['fnlwgt'],axis=1,inplace=True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   education       32561 non-null  object
#  3   education.num   32561 non-null  int64
#  4   marital.status  32561 non-null  object
#  5   occupation      32561 non-null  object
#  6   relationship    32561 non-null  object
#  7   race            32561 non-null  object
#  8   sex             32561 non-null  object
#  9   capital.gain    32561 non-null  int64
#  10  capital.loss    32561 non-null  int64
#  11  hours.per.week  32561 non-null  int64
#  12  native.country  32561 non-null  object
#  13  income          32561 non-null  object
# dtypes: int64(5), object(9)
# memory usage: 3.5+ MB

# %%
df3 = pd.concat([df1, df2['Customer City'], df69['customer_id'],df2['Customer Fname'],df2['Customer Lname'],df2['Customer Email'],df2['Customer Password'],df2['Order City'],df2['Order State'],df2['Order Region']],axis=1)
df3
# Out:
#         age workclass     education  education.num marital.status  \
# 0      90.0         ?       HS-grad            9.0        Widowed
# 1      82.0   Private       HS-grad            9.0        Widowed
# 2      66.0         ?  Some-college           10.0        Widowed
# 3      54.0   Private       7th-8th            4.0       Divorced
# 4      41.0   Private  Some-college           10.0      Separated
# ...     ...       ...           ...            ...            ...
# 50247   NaN       NaN           NaN            NaN            NaN
# 50248   NaN       NaN           NaN            NaN            NaN
# 50249   NaN       NaN           NaN            NaN            NaN
# 50250   NaN       NaN           NaN            NaN            NaN
# 50251   NaN       NaN           NaN            NaN            NaN
#
#               occupation   relationship   race     sex  capital.gain  ...  \
# 0                      ?  Not-in-family  White  Female           0.0  ...
# 1        Exec-managerial  Not-in-family  White  Female           0.0  ...
# 2                      ?      Unmarried  Black  Female           0.0  ...
# 3      Machine-op-inspct      Unmarried  White  Female           0.0  ...
# 4         Prof-specialty      Own-child  White  Female           0.0  ...
# ...                  ...            ...    ...     ...           ...  ...
# 50247                NaN            NaN    NaN     NaN           NaN  ...
# 50248                NaN            NaN    NaN     NaN           NaN  ...
# 50249                NaN            NaN    NaN     NaN           NaN  ...
# 50250                NaN            NaN    NaN     NaN           NaN  ...
# 50251                NaN            NaN    NaN     NaN           NaN  ...
#
#        income  Customer City  customer_id Customer Fname Customer Lname  \
# 0       <=50K       Oak Lawn  72c00ba8bc7           Mary         Barnes
# 1       <=50K         Caguas  b18a428ac77       Brittany          Smith
# 2       <=50K         Caguas  2fdd0374a03       Jennifer          Smith
# 3       <=50K         Caguas  dc6358b12c3           Mary          Smith
# 4       <=50K       Columbus  c12e35b23ad           Mary         Wright
# ...       ...            ...          ...            ...            ...
# 50247     NaN         Caguas          NaN           Mary       Mckenzie
# 50248     NaN     Toms River          NaN        Matthew     Montgomery
# 50249     NaN  San Francisco          NaN          David          Smith
# 50250     NaN       Portland          NaN         Hannah         Morton
# 50251     NaN         Caguas          NaN           Mary        Salazar
#
#       Customer Email Customer Password            Order City  \
# 0          XXXXXXXXX         XXXXXXXXX                Rimini
# 1          XXXXXXXXX         XXXXXXXXX                 Lille
# 2          XXXXXXXXX         XXXXXXXXX             Charleroi
# 3          XXXXXXXXX         XXXXXXXXX     Montecatini Terme
# 4          XXXXXXXXX         XXXXXXXXX        Recklinghausen
# ...              ...               ...                   ...
# 50247      XXXXXXXXX         XXXXXXXXX               Heerlen
# 50248      XXXXXXXXX         XXXXXXXXX               Swansea
# 50249      XXXXXXXXX         XXXXXXXXX                 Viena
# 50250      XXXXXXXXX         XXXXXXXXX  El Prat de Llobregat
# 50251      XXXXXXXXX         XXXXXXXXX             Estocolmo
#
#                          Order State     Order Region
# 0                      Emilia-Romaña  Southern Europe
# 1      Norte-Paso de Calais-Picardía   Western Europe
# 2                              Henao   Western Europe
# 3                            Toscana  Southern Europe
# 4        Renania del Norte-Westfalia   Western Europe
# ...                              ...              ...
# 50247                       Limburgo   Western Europe
# 50248                          Gales  Northern Europe
# 50249                          Viena   Western Europe
# 50250                       Cataluña  Southern Europe
# 50251                      Estocolmo  Northern Europe
#
# [50252 rows x 23 columns]

# %%
df4 = pd.concat([df3, df['PLACE_OF_RECEIVERS 1']],axis=1)
df4
# Out:
#         age workclass     education  education.num marital.status  \
# 0      90.0         ?       HS-grad            9.0        Widowed
# 1      82.0   Private       HS-grad            9.0        Widowed
# 2      66.0         ?  Some-college           10.0        Widowed
# 3      54.0   Private       7th-8th            4.0       Divorced
# 4      41.0   Private  Some-college           10.0      Separated
# ...     ...       ...           ...            ...            ...
# 50247   NaN       NaN           NaN            NaN            NaN
# 50248   NaN       NaN           NaN            NaN            NaN
# 50249   NaN       NaN           NaN            NaN            NaN
# 50250   NaN       NaN           NaN            NaN            NaN
# 50251   NaN       NaN           NaN            NaN            NaN
#
#               occupation   relationship   race     sex  capital.gain  ...  \
# 0                      ?  Not-in-family  White  Female           0.0  ...
# 1        Exec-managerial  Not-in-family  White  Female           0.0  ...
# 2                      ?      Unmarried  Black  Female           0.0  ...
# 3      Machine-op-inspct      Unmarried  White  Female           0.0  ...
# 4         Prof-specialty      Own-child  White  Female           0.0  ...
# ...                  ...            ...    ...     ...           ...  ...
# 50247                NaN            NaN    NaN     NaN           NaN  ...
# 50248                NaN            NaN    NaN     NaN           NaN  ...
# 50249                NaN            NaN    NaN     NaN           NaN  ...
# 50250                NaN            NaN    NaN     NaN           NaN  ...
# 50251                NaN            NaN    NaN     NaN           NaN  ...
#
#        Customer City  customer_id Customer Fname Customer Lname  \
# 0           Oak Lawn  72c00ba8bc7           Mary         Barnes
# 1             Caguas  b18a428ac77       Brittany          Smith
# 2             Caguas  2fdd0374a03       Jennifer          Smith
# 3             Caguas  dc6358b12c3           Mary          Smith
# 4           Columbus  c12e35b23ad           Mary         Wright
# ...              ...          ...            ...            ...
# 50247         Caguas          NaN           Mary       Mckenzie
# 50248     Toms River          NaN        Matthew     Montgomery
# 50249  San Francisco          NaN          David          Smith
# 50250       Portland          NaN         Hannah         Morton
# 50251         Caguas          NaN           Mary        Salazar
#
#       Customer Email Customer Password            Order City  \
# 0          XXXXXXXXX         XXXXXXXXX                Rimini
# 1          XXXXXXXXX         XXXXXXXXX                 Lille
# 2          XXXXXXXXX         XXXXXXXXX             Charleroi
# 3          XXXXXXXXX         XXXXXXXXX     Montecatini Terme
# 4          XXXXXXXXX         XXXXXXXXX        Recklinghausen
# ...              ...               ...                   ...
# 50247      XXXXXXXXX         XXXXXXXXX               Heerlen
# 50248      XXXXXXXXX         XXXXXXXXX               Swansea
# 50249      XXXXXXXXX         XXXXXXXXX                 Viena
# 50250      XXXXXXXXX         XXXXXXXXX  El Prat de Llobregat
# 50251      XXXXXXXXX         XXXXXXXXX             Estocolmo
#
#                          Order State     Order Region PLACE_OF_RECEIVERS 1
# 0                      Emilia-Romaña  Southern Europe  Chincoteague Island
# 1      Norte-Paso de Calais-Picardía   Western Europe               Exmore
# 2                              Henao   Western Europe        Lawrenceville
# 3                            Toscana  Southern Europe           Midlothian
# 4        Renania del Norte-Westfalia   Western Europe       Virginia Beach
# ...                              ...              ...                  ...
# 50247                       Limburgo   Western Europe                  NaN
# 50248                          Gales  Northern Europe                  NaN
# 50249                          Viena   Western Europe                  NaN
# 50250                       Cataluña  Southern Europe                  NaN
# 50251                      Estocolmo  Northern Europe                  NaN
#
# [50252 rows x 24 columns]

# %%
df4=df4.drop(index=df4.index[10006:50252])

# %%
df4.isna().sum()
# Out:
# age                     0
# workclass               0
# education               0
# education.num           0
# marital.status          0
# occupation              0
# relationship            0
# race                    0
# sex                     0
# capital.gain            0
# capital.loss            0
# hours.per.week          0
# native.country          0
# income                  0
# Customer City           0
# customer_id             1
# Customer Fname          0
# Customer Lname          0
# Customer Email          0
# Customer Password       0
# Order City              0
# Order State             0
# Order Region            0
# PLACE_OF_RECEIVERS 1    0
# dtype: int64

# %%
df4 = df4.dropna()

# %%
df4['workclass'] = df4['workclass'].replace('?', 'Private')
df4['occupation'] = df4['occupation'].replace('?', 'Prof-specialty')
df4['native.country'] = df4['native.country'].replace('?', 'United-States')
df4
# Out:
#         age         workclass     education  education.num  \
# 0      90.0           Private       HS-grad            9.0
# 1      82.0           Private       HS-grad            9.0
# 2      66.0           Private  Some-college           10.0
# 3      54.0           Private       7th-8th            4.0
# 4      41.0           Private  Some-college           10.0
# ...     ...               ...           ...            ...
# 10000  43.0           Private     Bachelors           13.0
# 10001  58.0           Private       HS-grad            9.0
# 10002  43.0  Self-emp-not-inc       HS-grad            9.0
# 10003  37.0           Private  Some-college           10.0
# 10004  21.0       Federal-gov          12th            8.0
#
#            marital.status         occupation   relationship   race     sex  \
# 0                 Widowed     Prof-specialty  Not-in-family  White  Female
# 1                 Widowed    Exec-managerial  Not-in-family  White  Female
# 2                 Widowed     Prof-specialty      Unmarried  Black  Female
# 3                Divorced  Machine-op-inspct      Unmarried  White  Female
# 4               Separated     Prof-specialty      Own-child  White  Female
# ...                   ...                ...            ...    ...     ...
# 10000            Divorced     Prof-specialty  Not-in-family  White    Male
# 10001             Widowed       Craft-repair      Unmarried  White    Male
# 10002  Married-civ-spouse              Sales        Husband  White    Male
# 10003           Separated     Prof-specialty      Unmarried  White    Male
# 10004       Never-married       Adm-clerical      Own-child  Black    Male
#
#        capital.gain  ...  Customer City  customer_id Customer Fname  \
# 0               0.0  ...       Oak Lawn  72c00ba8bc7           Mary
# 1               0.0  ...         Caguas  b18a428ac77       Brittany
# 2               0.0  ...         Caguas  2fdd0374a03       Jennifer
# 3               0.0  ...         Caguas  dc6358b12c3           Mary
# 4               0.0  ...       Columbus  c12e35b23ad           Mary
# ...             ...  ...            ...          ...            ...
# 10000           0.0  ...          Salem  42c56b99070          Terry
# 10001           0.0  ...        Buffalo  42c56b99071           Mary
# 10002           0.0  ...        Buffalo  42c56b99072           Mary
# 10003           0.0  ...         Caguas  42c56b99073         Nathan
# 10004           0.0  ...      Cleveland  42c56b99074          Billy
#
#       Customer Lname Customer Email Customer Password         Order City  \
# 0             Barnes      XXXXXXXXX         XXXXXXXXX             Rimini
# 1              Smith      XXXXXXXXX         XXXXXXXXX              Lille
# 2              Smith      XXXXXXXXX         XXXXXXXXX          Charleroi
# 3              Smith      XXXXXXXXX         XXXXXXXXX  Montecatini Terme
# 4             Wright      XXXXXXXXX         XXXXXXXXX     Recklinghausen
# ...              ...            ...               ...                ...
# 10000          Smith      XXXXXXXXX         XXXXXXXXX             Slupsk
# 10001          Clark      XXXXXXXXX         XXXXXXXXX              Vlore
# 10002          Clark      XXXXXXXXX         XXXXXXXXX              Vlore
# 10003          Adams      XXXXXXXXX         XXXXXXXXX        Arkhangelsk
# 10004          Weeks      XXXXXXXXX         XXXXXXXXX       Magnitogorsk
#
#                          Order State     Order Region PLACE_OF_RECEIVERS 1
# 0                      Emilia-Romaña  Southern Europe  Chincoteague Island
# 1      Norte-Paso de Calais-Picardía   Western Europe               Exmore
# 2                              Henao   Western Europe        Lawrenceville
# 3                            Toscana  Southern Europe           Midlothian
# 4        Renania del Norte-Westfalia   Western Europe       Virginia Beach
# ...                              ...              ...                  ...
# 10000                      Pomerania   Eastern Europe         Johnson City
# 10001                          Vlorë  Southern Europe         Johnson City
# 10002                          Vlorë  Southern Europe         Johnson City
# 10003                    Arjánguelsk   Eastern Europe         Johnson City
# 10004                    Cheliábinsk   Eastern Europe         Johnson City
#
# [10005 rows x 24 columns]

# %%
df4.to_csv(r"D:\Filechuan\New\Customer.csv", index=False)
