# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# Read Data

# %%
data = pd.read_csv("D:\Filechuan\dataset\VehicleInformation.csv")
df = data.copy()
df
# Out:
#        selling_price  km_driven    fuel       seller_type transmission  \
# 0             450000     145500  Diesel        Individual       Manual
# 1             370000     120000  Diesel        Individual       Manual
# 2             158000     140000  Petrol        Individual       Manual
# 3             225000     127000  Diesel        Individual       Manual
# 4             130000     120000  Petrol        Individual       Manual
# ...              ...        ...     ...               ...          ...
# 10007         625000      25538  Petrol  Trustmark Dealer       Manual
# 10008         550000      56494  Petrol  Trustmark Dealer       Manual
# 10009         750000      79328  Diesel  Trustmark Dealer       Manual
# 10010         650000       5621  Petrol  Trustmark Dealer    Automatic
# 10011         625000      25538  Petrol  Trustmark Dealer       Manual
#
#         owner  mileage (kmpl)  engine (CC) EngineSizeSimple  max_power(bhp)  \
# 0       First           23.40         1248             1400           74.00
# 1      Second           21.14         1498             1400          103.52
# 2       Third           17.70         1497             1400           78.00
# 3       First           23.00         1396             1400           90.00
# 4       First           16.10         1298             1400           88.20
# ...       ...             ...          ...              ...             ...
# 10007   First           16.78         1496              800           88.73
# 10008   First           18.20         1199              600           88.70
# 10009  Second           12.99         2494              600          100.60
# 10010   First           22.00         1197              700           81.80
# 10011   First           16.78         1496              800           88.73
#
#        seats            Driver_Name  Driver_MobileNo  \
# 0          5                 RAMESH       7082423013
# 1          5                 RAMESH       7082423014
# 2          5                   GIRI       7082423015
# 3          5                   RAVI       7082423016
# 4          5                  TAMIL       7082423017
# ...      ...                    ...              ...
# 10007      5  thippaswamy nayak K T       9036703936
# 10008      5        KUMMARI SAYAPPA       9502232573
# 10009      7               Sankar M       9486574971
# 10010      5      Iranna R Umachagi       8088718846
# 10011      5  thippaswamy nayak K T       9036703936
#
#                          torque LicenceStatus
# 0                190Nm@ 2000rpm      Licensed
# 1           250Nm@ 1500-2500rpm          SORN
# 2         12.7@ 2,700(kgm@ rpm)      Licensed
# 3      22.4 kgm at 1750-2750rpm          SORN
# 4         11.5@ 4,500(kgm@ rpm)      Licensed
# ...                         ...           ...
# 10007            132Nm@ 3000rpm          SORN
# 10008            110Nm@ 4800rpm      Licensed
# 10009       200Nm@ 1200-3600rpm          SORN
# 10010            113Nm@ 4200rpm      Licensed
# 10011            132Nm@ 3000rpm          SORN
#
# [10012 rows x 15 columns]

# %%
data1 = pd.read_csv("D:\Filechuan\dataset\VehicleType_USA.csv")
df1 = data1.copy()
df1
# Out:
#       vehicle_no                                vehicleType Current_Location  \
# 0       KA590408                           Mahindra LCV 1MT         New York
# 1     TN30BC5917                           Mahindra LCV 1MT         San Jose
# 2     TN22AR2748                           Mahindra LCV 1MT       Birmingham
# 3     TN28AQ0781                           Mahindra LCV 1MT         San Jose
# 4      TN68F1722                           Mahindra LCV 1MT           Boston
# ...          ...                                        ...              ...
# 9995   KA01D0911   40 FT Flat Bed Multi-Axle 27MT - Trailer         San Jose
# 9996   KA01D0911                     40 FT 3XL Trailer 35MT         New York
# 9997   KA01D0911                     40 FT 3XL Trailer 35MT         San Jose
# 9998  RJ42GA1977                     40 FT 3XL Trailer 35MT       Birmingham
# 9999   AP13X6669  40 FT Flat Bed Double-Axle 21MT - Trailer         San Jose
#
#            GenModel                                    name  year
# 0        ABARTH 500                  Maruti Swift Dzire VDI  2014
# 1        ABARTH 595            Skoda Rapid 1.5 TDI Ambition  2014
# 2        ABARTH 595                Honda City 2017-2020 EXi  2006
# 3        ABARTH 595               Hyundai i20 Sportz Diesel  2010
# 4        ABARTH 595                  Maruti Swift VXI BSIII  2007
# ...             ...                                     ...   ...
# 9995  JEEP WRANGLER                 Maruti Baleno Alpha 1.3  2018
# 9996  JEEP WRANGLER                           Honda Jazz VX  2016
# 9997  JEEP WRANGLER  Toyota Innova 2.5 VX (Diesel) 7 Seater  2013
# 9998  JEEP WRANGLER                Maruti Swift AMT VVT VXI  2019
# 9999  JEEP WRANGLER                         Toyota Etios VX  2017
#
# [10000 rows x 6 columns]

# %% [markdown]
# Data Processing

# %%
df2= pd.concat([df1, df], axis=1)
df2
# Out:
#        vehicle_no       vehicleType Current_Location    GenModel  \
# 0        KA590408  Mahindra LCV 1MT         New York  ABARTH 500
# 1      TN30BC5917  Mahindra LCV 1MT         San Jose  ABARTH 595
# 2      TN22AR2748  Mahindra LCV 1MT       Birmingham  ABARTH 595
# 3      TN28AQ0781  Mahindra LCV 1MT         San Jose  ABARTH 595
# 4       TN68F1722  Mahindra LCV 1MT           Boston  ABARTH 595
# ...           ...               ...              ...         ...
# 10007         NaN               NaN              NaN         NaN
# 10008         NaN               NaN              NaN         NaN
# 10009         NaN               NaN              NaN         NaN
# 10010         NaN               NaN              NaN         NaN
# 10011         NaN               NaN              NaN         NaN
#
#                                name    year  selling_price  km_driven    fuel  \
# 0            Maruti Swift Dzire VDI  2014.0         450000     145500  Diesel
# 1      Skoda Rapid 1.5 TDI Ambition  2014.0         370000     120000  Diesel
# 2          Honda City 2017-2020 EXi  2006.0         158000     140000  Petrol
# 3         Hyundai i20 Sportz Diesel  2010.0         225000     127000  Diesel
# 4            Maruti Swift VXI BSIII  2007.0         130000     120000  Petrol
# ...                             ...     ...            ...        ...     ...
# 10007                           NaN     NaN         625000      25538  Petrol
# 10008                           NaN     NaN         550000      56494  Petrol
# 10009                           NaN     NaN         750000      79328  Diesel
# 10010                           NaN     NaN         650000       5621  Petrol
# 10011                           NaN     NaN         625000      25538  Petrol
#
#             seller_type  ...   owner mileage (kmpl)  engine (CC)  \
# 0            Individual  ...   First          23.40         1248
# 1            Individual  ...  Second          21.14         1498
# 2            Individual  ...   Third          17.70         1497
# 3            Individual  ...   First          23.00         1396
# 4            Individual  ...   First          16.10         1298
# ...                 ...  ...     ...            ...          ...
# 10007  Trustmark Dealer  ...   First          16.78         1496
# 10008  Trustmark Dealer  ...   First          18.20         1199
# 10009  Trustmark Dealer  ...  Second          12.99         2494
# 10010  Trustmark Dealer  ...   First          22.00         1197
# 10011  Trustmark Dealer  ...   First          16.78         1496
#
#        EngineSizeSimple max_power(bhp)  seats            Driver_Name  \
# 0                  1400          74.00      5                 RAMESH
# 1                  1400         103.52      5                 RAMESH
# 2                  1400          78.00      5                   GIRI
# 3                  1400          90.00      5                   RAVI
# 4                  1400          88.20      5                  TAMIL
# ...                 ...            ...    ...                    ...
# 10007               800          88.73      5  thippaswamy nayak K T
# 10008               600          88.70      5        KUMMARI SAYAPPA
# 10009               600         100.60      7               Sankar M
# 10010               700          81.80      5      Iranna R Umachagi
# 10011               800          88.73      5  thippaswamy nayak K T
#
#       Driver_MobileNo                    torque LicenceStatus
# 0          7082423013            190Nm@ 2000rpm      Licensed
# 1          7082423014       250Nm@ 1500-2500rpm          SORN
# 2          7082423015     12.7@ 2,700(kgm@ rpm)      Licensed
# 3          7082423016  22.4 kgm at 1750-2750rpm          SORN
# 4          7082423017     11.5@ 4,500(kgm@ rpm)      Licensed
# ...               ...                       ...           ...
# 10007      9036703936            132Nm@ 3000rpm          SORN
# 10008      9502232573            110Nm@ 4800rpm      Licensed
# 10009      9486574971       200Nm@ 1200-3600rpm          SORN
# 10010      8088718846            113Nm@ 4200rpm      Licensed
# 10011      9036703936            132Nm@ 3000rpm          SORN
#
# [10012 rows x 21 columns]

# %%
df2.isna().sum()
# Out:
# vehicle_no           12
# vehicleType          12
# Current_Location     12
# GenModel             28
# name                 15
# year                 12
# selling_price         0
# km_driven             0
# fuel                  0
# seller_type           0
# transmission          0
# owner                 0
# mileage (kmpl)        0
# engine (CC)           0
# EngineSizeSimple      0
# max_power(bhp)        0
# seats                 0
# Driver_Name           0
# Driver_MobileNo       0
# torque              269
# LicenceStatus         0
# dtype: int64

# %%
df2.drop(["torque"],axis=1,inplace=True)
df2 = df2.dropna()
df2
# Out:
#       vehicle_no                                vehicleType Current_Location  \
# 0       KA590408                           Mahindra LCV 1MT         New York
# 1     TN30BC5917                           Mahindra LCV 1MT         San Jose
# 2     TN22AR2748                           Mahindra LCV 1MT       Birmingham
# 3     TN28AQ0781                           Mahindra LCV 1MT         San Jose
# 4      TN68F1722                           Mahindra LCV 1MT           Boston
# ...          ...                                        ...              ...
# 9995   KA01D0911   40 FT Flat Bed Multi-Axle 27MT - Trailer         San Jose
# 9996   KA01D0911                     40 FT 3XL Trailer 35MT         New York
# 9997   KA01D0911                     40 FT 3XL Trailer 35MT         San Jose
# 9998  RJ42GA1977                     40 FT 3XL Trailer 35MT       Birmingham
# 9999   AP13X6669  40 FT Flat Bed Double-Axle 21MT - Trailer         San Jose
#
#            GenModel                                    name    year  \
# 0        ABARTH 500                  Maruti Swift Dzire VDI  2014.0
# 1        ABARTH 595            Skoda Rapid 1.5 TDI Ambition  2014.0
# 2        ABARTH 595                Honda City 2017-2020 EXi  2006.0
# 3        ABARTH 595               Hyundai i20 Sportz Diesel  2010.0
# 4        ABARTH 595                  Maruti Swift VXI BSIII  2007.0
# ...             ...                                     ...     ...
# 9995  JEEP WRANGLER                 Maruti Baleno Alpha 1.3  2018.0
# 9996  JEEP WRANGLER                           Honda Jazz VX  2016.0
# 9997  JEEP WRANGLER  Toyota Innova 2.5 VX (Diesel) 7 Seater  2013.0
# 9998  JEEP WRANGLER                Maruti Swift AMT VVT VXI  2019.0
# 9999  JEEP WRANGLER                         Toyota Etios VX  2017.0
#
#       selling_price  km_driven    fuel       seller_type transmission   owner  \
# 0            450000     145500  Diesel        Individual       Manual   First
# 1            370000     120000  Diesel        Individual       Manual  Second
# 2            158000     140000  Petrol        Individual       Manual   Third
# 3            225000     127000  Diesel        Individual       Manual   First
# 4            130000     120000  Petrol        Individual       Manual   First
# ...             ...        ...     ...               ...          ...     ...
# 9995         740000      38817  Diesel            Dealer       Manual   First
# 9996         550000      56494  Petrol  Trustmark Dealer       Manual   First
# 9997         750000      79328  Diesel  Trustmark Dealer       Manual  Second
# 9998         650000       5621  Petrol  Trustmark Dealer    Automatic   First
# 9999         625000      25538  Petrol  Trustmark Dealer       Manual   First
#
#       mileage (kmpl)  engine (CC) EngineSizeSimple  max_power(bhp)  seats  \
# 0              23.40         1248             1400           74.00      5
# 1              21.14         1498             1400          103.52      5
# 2              17.70         1497             1400           78.00      5
# 3              23.00         1396             1400           90.00      5
# 4              16.10         1298             1400           88.20      5
# ...              ...          ...              ...             ...    ...
# 9995           27.39         1248              300           74.00      5
# 9996           18.20         1199              600           88.70      5
# 9997           12.99         2494              600          100.60      7
# 9998           22.00         1197              700           81.80      5
# 9999           16.78         1496              800           88.73      5
#
#                 Driver_Name  Driver_MobileNo LicenceStatus
# 0                    RAMESH       7082423013      Licensed
# 1                    RAMESH       7082423014          SORN
# 2                      GIRI       7082423015      Licensed
# 3                      RAVI       7082423016          SORN
# 4                     TAMIL       7082423017      Licensed
# ...                     ...              ...           ...
# 9995               RAMULU K       9704418284          SORN
# 9996        KUMMARI SAYAPPA       9502232573      Licensed
# 9997               Sankar M       9486574971          SORN
# 9998      Iranna R Umachagi       8088718846      Licensed
# 9999  thippaswamy nayak K T       9036703936          SORN
#
# [9982 rows x 20 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9982 entries, 0 to 9999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   vehicle_no        9982 non-null   object
#  1   vehicleType       9982 non-null   object
#  2   Current_Location  9982 non-null   object
#  3   GenModel          9982 non-null   object
#  4   name              9982 non-null   object
#  5   year              9982 non-null   float64
#  6   selling_price     9982 non-null   int64
#  7   km_driven         9982 non-null   int64
#  8   fuel              9982 non-null   object
#  9   seller_type       9982 non-null   object
#  10  transmission      9982 non-null   object
#  11  owner             9982 non-null   object
#  12  mileage (kmpl)    9982 non-null   float64
#  13  engine (CC)       9982 non-null   int64
#  14  EngineSizeSimple  9982 non-null   object
#  15  max_power(bhp)    9982 non-null   float64
#  16  seats             9982 non-null   int64
#  17  Driver_Name       9982 non-null   object
#  18  Driver_MobileNo   9982 non-null   int64
#  19  LicenceStatus     9982 non-null   object
# dtypes: float64(3), int64(5), object(12)
# memory usage: 1.6+ MB

# %%
df2['max_power(bhp)']=df2['max_power(bhp)'].astype('float')
# Out:
# C:\Users\VNPT10\AppData\Local\Temp\ipykernel_13584\754359579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['max_power(bhp)']=df2['max_power(bhp)'].astype('float')

# %%
df2.to_csv(r"D:\Filechuan\New\Vehicle.csv", index=False)
