# %% [markdown]
# Read Data

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
data_frame_1= pd.read_csv("D:/Filechuan/dataset/FleetJourney_EcomUStime.csv")
df1=data_frame_1.copy()
df1
# Out:
#       SENDERS_DATE RECEIVERS_DATE  TRANSPORTATION_DISTANCE_IN_KM ontime delay  \
# 0       18/05/2021     28/06/2021                          320.0     No   Yes
# 1       18/05/2021     28/06/2021                          103.0    Yes    No
# 2        11/4/2021     22/05/2021                          300.0    Yes    No
# 3       19/05/2021     29/06/2021                           61.0    Yes    No
# 4       18/05/2021     28/06/2021                          240.0    Yes    No
# ...            ...            ...                            ...    ...   ...
# 10000   19/04/2021     30/05/2021                           31.0     No   Yes
# 10001   20/04/2021     31/05/2021                           32.0     No   Yes
# 10002   21/04/2021       1/6/2021                           33.0     No   Yes
# 10003   22/04/2021       2/6/2021                           34.0     No   Yes
# 10004   23/04/2021       3/6/2021                           35.0     No   Yes
#
#       PREDICTED_DELIVERED_DATE  vehicle_no  \
# 0                   30/06/2021    KA590408
# 1                   30/06/2021  TN30BC5917
# 2                   24/05/2021  TN22AR2748
# 3                   29/06/2021  TN28AQ0781
# 4                   28/06/2021   TN68F1722
# ...                        ...         ...
# 10000                 1/6/2021   AP13X6670
# 10001                 2/6/2021   AP13X6671
# 10002                 3/6/2021   AP13X6672
# 10003                 4/6/2021   AP13X6673
# 10004                 5/6/2021   AP13X6674
#
#                                      vehicleType            Driver_Name  \
# 0                               Mahindra LCV 1MT                 RAMESH
# 1                               Mahindra LCV 1MT                 RAMESH
# 2                               Mahindra LCV 1MT                   GIRI
# 3                               Mahindra LCV 1MT                   RAVI
# 4                               Mahindra LCV 1MT                  TAMIL
# ...                                          ...                    ...
# 10000  41 FT Flat Bed Double-Axle 21MT - Trailer  thippaswamy nayak K T
# 10001  42 FT Flat Bed Double-Axle 21MT - Trailer  thippaswamy nayak K T
# 10002  43 FT Flat Bed Double-Axle 21MT - Trailer  thippaswamy nayak K T
# 10003  44 FT Flat Bed Double-Axle 21MT - Trailer  thippaswamy nayak K T
# 10004  45 FT Flat Bed Double-Axle 21MT - Trailer  thippaswamy nayak K T
#
#        Driver_MobileNo  customer_id First_name  supplierID  \
# 0           7082423013  72c00ba8bc7      James  VIJEXHOSR7
# 1           7082423014  b18a428ac77  Josephine  VJLEXSHE09
# 2           7082423015  2fdd0374a03        Art  GSTEXLAK1Q
# 3           7082423016  dc6358b12c3      Lenna  ARVEXNAM09
# 4           7082423017  c12e35b23ad    Donette  SRTEXKOR96
# ...                ...          ...        ...         ...
# 10000       9036703937  42c56b99070       Mary       59071
# 10001       9036703938  42c56b99071   Jennifer       59072
# 10002       9036703939  42c56b99072     Martha       59073
# 10003       9036703940  42c56b99073     Evelyn       59074
# 10004       9036703941  42c56b99074  Guinevere       59075
#
#             supplierNameCode             Material Shipped
# 0            VIJAY TRANSPORT        BRACKET / GRAB HANDLE
# 1               VJ LOGISTICS        ZB MODEL PLATE / 3143
# 2             G.S. TRANSPORT             LETTERING / FUSO
# 3          ARVINTH TRANSPORT     LU STRUT RA / RADIUS ROD
# 4              SR TRANSPORTS         WISHBONE / V ROD/HDT
# ...                      ...                          ...
# 10000  VINOD KAPOOR AND SONS  THRUST WASHER TSIDE CHAMFER
# 10001  VINOD KAPOOR AND SONS  THRUST WASHER TSIDE CHAMFER
# 10002  VINOD KAPOOR AND SONS  THRUST WASHER TSIDE CHAMFER
# 10003  VINOD KAPOOR AND SONS  THRUST WASHER TSIDE CHAMFER
# 10004  VINOD KAPOOR AND SONS  THRUST WASHER TSIDE CHAMFER
#
# [10005 rows x 15 columns]

# %%
data_frame_2= pd.read_csv("D:/Filechuan/dataset/FleetJourneyorderinfor.csv")
df2=data_frame_2.copy()
df2
# Out:
#            order_id order_id_date  vehicle_no  customer_id PLACE_OF_SENDERS  \
# 0       d792cb16214    15/05/2021    KA590408  72c00ba8bc7         New York
# 1       0d7a144bdd3    15/05/2021  TN30BC5917  b18a428ac77         San Jose
# 2       57da4fc703e      8/4/2021  TN22AR2748  2fdd0374a03       Birmingham
# 3       1b038114c75    16/05/2021  TN28AQ0781  dc6358b12c3         San Jose
# 4       bb4e55b4fd9    15/05/2021   TN68F1722  c12e35b23ad           Boston
# ...             ...           ...         ...          ...              ...
# 10015  57f78c2d0d17      2/5/2021   AP13X6686          NaN         San Jose
# 10016  57f78c2d0d18      3/5/2021   AP13X6687          NaN         San Jose
# 10017  57f78c2d0d19      4/5/2021   AP13X6688          NaN         San Jose
# 10018  57f78c2d0d20      5/5/2021   AP13X6689          NaN         San Jose
# 10019  57f78c2d0d21      6/5/2021   AP13X6690          NaN         San Jose
#
#       PLACE_OF_RECEIVERS 1 PLACE_OF_RECEIVERS 2 PLACE_OF_RECEIVERS 3  \
# 0      Chincoteague Island           Fort Wayne                 Mesa
# 1                   Exmore               Newark              Garland
# 2            Lawrenceville            Arlington           Scottsdale
# 3               Midlothian           Fort Wayne                Plano
# 4           Virginia Beach          Baton Rouge              Garland
# ...                    ...                  ...                  ...
# 10015                  NaN                  NaN              Garland
# 10016                  NaN                  NaN              Garland
# 10017         Johnson City                  NaN              Garland
# 10018         Johnson City            Charlotte                  NaN
# 10019         Johnson City            Charlotte              Garland
#
#        Unnamed: 8
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 10015         NaN
# 10016         NaN
# 10017         NaN
# 10018         NaN
# 10019         NaN
#
# [10020 rows x 9 columns]

# %%
df4=pd.read_csv("D:/Filechuan/dataset/adult.csv", dtype='unicode')
df4
# Out:
#       Customer Id Customer Fname Customer Lname  age workclass     education  \
# 0             542           Mary          Smith   90         ?       HS-grad
# 1           11329         Hannah          Smith   82   Private       HS-grad
# 2            3570           Mary         Nelson   66         ?  Some-college
# 3             650         Austin         Sexton   54   Private       7th-8th
# 4            9353        Michael          Scott   41   Private  Some-college
# ...           ...            ...            ...  ...       ...           ...
# 50247        1115          Henry          Smith  NaN       NaN           NaN
# 50248        9259         Thomas          Roman  NaN       NaN           NaN
# 50249       12107         Sharon      Patterson  NaN       NaN           NaN
# 50250        6253           Mary       Peterson  NaN       NaN           NaN
# 50251        8430         Gloria          Smith  NaN       NaN           NaN
#
#       education.num marital.status         occupation   relationship   race  \
# 0                 9        Widowed                  ?  Not-in-family  White
# 1                 9        Widowed    Exec-managerial  Not-in-family  White
# 2                10        Widowed                  ?      Unmarried  Black
# 3                 4       Divorced  Machine-op-inspct      Unmarried  White
# 4                10      Separated     Prof-specialty      Own-child  White
# ...             ...            ...                ...            ...    ...
# 50247           NaN            NaN                NaN            NaN    NaN
# 50248           NaN            NaN                NaN            NaN    NaN
# 50249           NaN            NaN                NaN            NaN    NaN
# 50250           NaN            NaN                NaN            NaN    NaN
# 50251           NaN            NaN                NaN            NaN    NaN
#
#           sex capital.gain capital.loss hours.per.week native.country income  \
# 0      Female            0         4356             40  United-States  <=50K
# 1      Female            0         4356             18  United-States  <=50K
# 2      Female            0         4356             40  United-States  <=50K
# 3      Female            0         3900             40  United-States  <=50K
# 4      Female            0         3900             40  United-States  <=50K
# ...       ...          ...          ...            ...            ...    ...
# 50247     NaN          NaN          NaN            NaN            NaN    NaN
# 50248     NaN          NaN          NaN            NaN            NaN    NaN
# 50249     NaN          NaN          NaN            NaN            NaN    NaN
# 50250     NaN          NaN          NaN            NaN            NaN    NaN
# 50251     NaN          NaN          NaN            NaN            NaN    NaN
#
#        PLACE_OF_RECEIVERS  Customer Email Customer Password
# 0      Chincoteague Island      XXXXXXXXX         XXXXXXXXX
# 1                   Exmore      XXXXXXXXX         XXXXXXXXX
# 2            Lawrenceville      XXXXXXXXX         XXXXXXXXX
# 3               Midlothian      XXXXXXXXX         XXXXXXXXX
# 4           Virginia Beach      XXXXXXXXX         XXXXXXXXX
# ...                    ...            ...               ...
# 50247                  NaN      XXXXXXXXX         XXXXXXXXX
# 50248                  NaN      XXXXXXXXX         XXXXXXXXX
# 50249                  NaN      XXXXXXXXX         XXXXXXXXX
# 50250                  NaN      XXXXXXXXX         XXXXXXXXX
# 50251                  NaN      XXXXXXXXX         XXXXXXXXX
#
# [50252 rows x 20 columns]

# %% [markdown]
# Data Processing

# %%
df1.describe()
# Out:
#        TRANSPORTATION_DISTANCE_IN_KM  Driver_MobileNo
# count                   10005.000000     1.000500e+04
# mean                      648.696072     7.831474e+09
# std                       918.371841     1.099220e+09
# min                         0.000000     6.000546e+09
# 25%                        40.000000     7.082424e+09
# 50%                       148.000000     7.082425e+09
# 75%                      1000.000000     8.917471e+09
# max                      2954.700000     1.000000e+10

# %%
df1.shape
# Out:
# (10005, 15)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10005 entries, 0 to 10004
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   SENDERS_DATE                   10004 non-null  object
#  1   RECEIVERS_DATE                 10005 non-null  object
#  2   TRANSPORTATION_DISTANCE_IN_KM  10005 non-null  float64
#  3   ontime                         10005 non-null  object
#  4   delay                          10005 non-null  object
#  5   PREDICTED_DELIVERED_DATE       10005 non-null  object
#  6   vehicle_no                     10005 non-null  object
#  7   vehicleType                    10005 non-null  object
#  8   Driver_Name                    10005 non-null  object
#  9   Driver_MobileNo                10005 non-null  int64
#  10  customer_id                    10005 non-null  object
#  11  First_name                     10005 non-null  object
#  12  supplierID                     10005 non-null  object
#  13  supplierNameCode               10005 non-null  object
#  14  Material Shipped               10005 non-null  object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 1.1+ MB

# %%
df3= pd.concat([df1, df2], axis=1)
df3
# Out:
#       SENDERS_DATE RECEIVERS_DATE  TRANSPORTATION_DISTANCE_IN_KM ontime delay  \
# 0       18/05/2021     28/06/2021                          320.0     No   Yes
# 1       18/05/2021     28/06/2021                          103.0    Yes    No
# 2        11/4/2021     22/05/2021                          300.0    Yes    No
# 3       19/05/2021     29/06/2021                           61.0    Yes    No
# 4       18/05/2021     28/06/2021                          240.0    Yes    No
# ...            ...            ...                            ...    ...   ...
# 10015          NaN            NaN                            NaN    NaN   NaN
# 10016          NaN            NaN                            NaN    NaN   NaN
# 10017          NaN            NaN                            NaN    NaN   NaN
# 10018          NaN            NaN                            NaN    NaN   NaN
# 10019          NaN            NaN                            NaN    NaN   NaN
#
#       PREDICTED_DELIVERED_DATE  vehicle_no       vehicleType Driver_Name  \
# 0                   30/06/2021    KA590408  Mahindra LCV 1MT      RAMESH
# 1                   30/06/2021  TN30BC5917  Mahindra LCV 1MT      RAMESH
# 2                   24/05/2021  TN22AR2748  Mahindra LCV 1MT        GIRI
# 3                   29/06/2021  TN28AQ0781  Mahindra LCV 1MT        RAVI
# 4                   28/06/2021   TN68F1722  Mahindra LCV 1MT       TAMIL
# ...                        ...         ...               ...         ...
# 10015                      NaN         NaN               NaN         NaN
# 10016                      NaN         NaN               NaN         NaN
# 10017                      NaN         NaN               NaN         NaN
# 10018                      NaN         NaN               NaN         NaN
# 10019                      NaN         NaN               NaN         NaN
#
#        Driver_MobileNo  ...          Material Shipped      order_id  \
# 0         7.082423e+09  ...     BRACKET / GRAB HANDLE   d792cb16214
# 1         7.082423e+09  ...     ZB MODEL PLATE / 3143   0d7a144bdd3
# 2         7.082423e+09  ...          LETTERING / FUSO   57da4fc703e
# 3         7.082423e+09  ...  LU STRUT RA / RADIUS ROD   1b038114c75
# 4         7.082423e+09  ...      WISHBONE / V ROD/HDT   bb4e55b4fd9
# ...                ...  ...                       ...           ...
# 10015              NaN  ...                       NaN  57f78c2d0d17
# 10016              NaN  ...                       NaN  57f78c2d0d18
# 10017              NaN  ...                       NaN  57f78c2d0d19
# 10018              NaN  ...                       NaN  57f78c2d0d20
# 10019              NaN  ...                       NaN  57f78c2d0d21
#
#       order_id_date  vehicle_no  customer_id PLACE_OF_SENDERS  \
# 0        15/05/2021    KA590408  72c00ba8bc7         New York
# 1        15/05/2021  TN30BC5917  b18a428ac77         San Jose
# 2          8/4/2021  TN22AR2748  2fdd0374a03       Birmingham
# 3        16/05/2021  TN28AQ0781  dc6358b12c3         San Jose
# 4        15/05/2021   TN68F1722  c12e35b23ad           Boston
# ...             ...         ...          ...              ...
# 10015      2/5/2021   AP13X6686          NaN         San Jose
# 10016      3/5/2021   AP13X6687          NaN         San Jose
# 10017      4/5/2021   AP13X6688          NaN         San Jose
# 10018      5/5/2021   AP13X6689          NaN         San Jose
# 10019      6/5/2021   AP13X6690          NaN         San Jose
#
#       PLACE_OF_RECEIVERS 1 PLACE_OF_RECEIVERS 2 PLACE_OF_RECEIVERS 3  \
# 0      Chincoteague Island           Fort Wayne                 Mesa
# 1                   Exmore               Newark              Garland
# 2            Lawrenceville            Arlington           Scottsdale
# 3               Midlothian           Fort Wayne                Plano
# 4           Virginia Beach          Baton Rouge              Garland
# ...                    ...                  ...                  ...
# 10015                  NaN                  NaN              Garland
# 10016                  NaN                  NaN              Garland
# 10017         Johnson City                  NaN              Garland
# 10018         Johnson City            Charlotte                  NaN
# 10019         Johnson City            Charlotte              Garland
#
#       Unnamed: 8
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 10015        NaN
# 10016        NaN
# 10017        NaN
# 10018        NaN
# 10019        NaN
#
# [10020 rows x 24 columns]

# %%
df3.isna().sum()
# Out:
# SENDERS_DATE                        16
# RECEIVERS_DATE                      15
# TRANSPORTATION_DISTANCE_IN_KM       15
# ontime                              15
# delay                               15
# PREDICTED_DELIVERED_DATE            15
# vehicle_no                          15
# vehicleType                         15
# Driver_Name                         15
# Driver_MobileNo                     15
# customer_id                         15
# First_name                          15
# supplierID                          15
# supplierNameCode                    15
# Material Shipped                    15
# order_id                             0
# order_id_date                        0
# vehicle_no                           0
# customer_id                         15
# PLACE_OF_SENDERS                     0
# PLACE_OF_RECEIVERS 1                 6
# PLACE_OF_RECEIVERS 2                12
# PLACE_OF_RECEIVERS 3                 4
# Unnamed: 8                       10020
# dtype: int64

# %%
filt1=df3[df3['SENDERS_DATE'].isna()]
filt1
# Out:
#       SENDERS_DATE RECEIVERS_DATE  TRANSPORTATION_DISTANCE_IN_KM ontime delay  \
# 7691           NaN      10/2/1900                          148.0     No   Yes
# 10005          NaN            NaN                            NaN    NaN   NaN
# 10006          NaN            NaN                            NaN    NaN   NaN
# 10007          NaN            NaN                            NaN    NaN   NaN
# 10008          NaN            NaN                            NaN    NaN   NaN
# 10009          NaN            NaN                            NaN    NaN   NaN
# 10010          NaN            NaN                            NaN    NaN   NaN
# 10011          NaN            NaN                            NaN    NaN   NaN
# 10012          NaN            NaN                            NaN    NaN   NaN
# 10013          NaN            NaN                            NaN    NaN   NaN
# 10014          NaN            NaN                            NaN    NaN   NaN
# 10015          NaN            NaN                            NaN    NaN   NaN
# 10016          NaN            NaN                            NaN    NaN   NaN
# 10017          NaN            NaN                            NaN    NaN   NaN
# 10018          NaN            NaN                            NaN    NaN   NaN
# 10019          NaN            NaN                            NaN    NaN   NaN
#
#       PREDICTED_DELIVERED_DATE  vehicle_no             vehicleType  \
# 7691                 12/2/1900  HR55AF1978  40 FT 3XL Trailer 35MT
# 10005                      NaN         NaN                     NaN
# 10006                      NaN         NaN                     NaN
# 10007                      NaN         NaN                     NaN
# 10008                      NaN         NaN                     NaN
# 10009                      NaN         NaN                     NaN
# 10010                      NaN         NaN                     NaN
# 10011                      NaN         NaN                     NaN
# 10012                      NaN         NaN                     NaN
# 10013                      NaN         NaN                     NaN
# 10014                      NaN         NaN                     NaN
# 10015                      NaN         NaN                     NaN
# 10016                      NaN         NaN                     NaN
# 10017                      NaN         NaN                     NaN
# 10018                      NaN         NaN                     NaN
# 10019                      NaN         NaN                     NaN
#
#       Driver_Name  Driver_MobileNo  ... Material Shipped      order_id  \
# 7691     SIGAMANI     7.082424e+09  ...      GRS STARTER   b87bc2c75ce
# 10005         NaN              NaN  ...              NaN   57f78c2d0d7
# 10006         NaN              NaN  ...              NaN   57f78c2d0d8
# 10007         NaN              NaN  ...              NaN   57f78c2d0d9
# 10008         NaN              NaN  ...              NaN  57f78c2d0d10
# 10009         NaN              NaN  ...              NaN  57f78c2d0d11
# 10010         NaN              NaN  ...              NaN  57f78c2d0d12
# 10011         NaN              NaN  ...              NaN  57f78c2d0d13
# 10012         NaN              NaN  ...              NaN  57f78c2d0d14
# 10013         NaN              NaN  ...              NaN  57f78c2d0d15
# 10014         NaN              NaN  ...              NaN  57f78c2d0d16
# 10015         NaN              NaN  ...              NaN  57f78c2d0d17
# 10016         NaN              NaN  ...              NaN  57f78c2d0d18
# 10017         NaN              NaN  ...              NaN  57f78c2d0d19
# 10018         NaN              NaN  ...              NaN  57f78c2d0d20
# 10019         NaN              NaN  ...              NaN  57f78c2d0d21
#
#       order_id_date vehicle_no  customer_id PLACE_OF_SENDERS  \
# 7691     25/06/2021   KA029324  0b86f6de25e         New York
# 10005    22/04/2021  AP13X6676          NaN         San Jose
# 10006    23/04/2021  AP13X6677          NaN         San Jose
# 10007    24/04/2021  AP13X6678          NaN         San Jose
# 10008    25/04/2021  AP13X6679          NaN         San Jose
# 10009    26/04/2021  AP13X6680          NaN         San Jose
# 10010    27/04/2021  AP13X6681          NaN         San Jose
# 10011    28/04/2021  AP13X6682          NaN         San Jose
# 10012    29/04/2021  AP13X6683          NaN         San Jose
# 10013    30/04/2021  AP13X6684          NaN         San Jose
# 10014      1/5/2021  AP13X6685          NaN         San Jose
# 10015      2/5/2021  AP13X6686          NaN         San Jose
# 10016      3/5/2021  AP13X6687          NaN         San Jose
# 10017      4/5/2021  AP13X6688          NaN         San Jose
# 10018      5/5/2021  AP13X6689          NaN         San Jose
# 10019      6/5/2021  AP13X6690          NaN         San Jose
#
#       PLACE_OF_RECEIVERS 1 PLACE_OF_RECEIVERS 2 PLACE_OF_RECEIVERS 3  \
# 7691               Memphis          Baton Rouge                 Mesa
# 10005         Johnson City            Charlotte              Garland
# 10006         Johnson City                  NaN                  NaN
# 10007         Johnson City                  NaN              Garland
# 10008         Johnson City                  NaN              Garland
# 10009         Johnson City                  NaN              Garland
# 10010         Johnson City                  NaN              Garland
# 10011                  NaN                  NaN              Garland
# 10012                  NaN                  NaN              Garland
# 10013                  NaN                  NaN                  NaN
# 10014                  NaN                  NaN              Garland
# 10015                  NaN                  NaN              Garland
# 10016                  NaN                  NaN              Garland
# 10017         Johnson City                  NaN              Garland
# 10018         Johnson City            Charlotte                  NaN
# 10019         Johnson City            Charlotte              Garland
#
#       Unnamed: 8
# 7691         NaN
# 10005        NaN
# 10006        NaN
# 10007        NaN
# 10008        NaN
# 10009        NaN
# 10010        NaN
# 10011        NaN
# 10012        NaN
# 10013        NaN
# 10014        NaN
# 10015        NaN
# 10016        NaN
# 10017        NaN
# 10018        NaN
# 10019        NaN
#
# [16 rows x 24 columns]

# %%
filt1.loc[filt1.order_id == '99e25010475','SENDERS_DATE']= '06/09/2021'
filt1.loc[filt1.order_id == '99e25010475','RECEIVERS_DATE']= '15/09/2021'
filt1
df3[df3['SENDERS_DATE'].isna()]=filt1

# %%
df3.isna().sum()
# Out:
# SENDERS_DATE                        16
# RECEIVERS_DATE                      15
# TRANSPORTATION_DISTANCE_IN_KM       15
# ontime                              15
# delay                               15
# PREDICTED_DELIVERED_DATE            15
# vehicle_no                          15
# vehicleType                         15
# Driver_Name                         15
# Driver_MobileNo                     15
# customer_id                         15
# First_name                          15
# supplierID                          15
# supplierNameCode                    15
# Material Shipped                    15
# order_id                             0
# order_id_date                        0
# vehicle_no                           0
# customer_id                         15
# PLACE_OF_SENDERS                     0
# PLACE_OF_RECEIVERS 1                 6
# PLACE_OF_RECEIVERS 2                12
# PLACE_OF_RECEIVERS 3                 4
# Unnamed: 8                       10020
# dtype: int64

# %%
df3=df3.join(df4['Customer Fname'])
df3=df3.join(df4['Customer Lname'])
df3
# Out:
#       SENDERS_DATE RECEIVERS_DATE  TRANSPORTATION_DISTANCE_IN_KM ontime delay  \
# 0       18/05/2021     28/06/2021                          320.0     No   Yes
# 1       18/05/2021     28/06/2021                          103.0    Yes    No
# 2        11/4/2021     22/05/2021                          300.0    Yes    No
# 3       19/05/2021     29/06/2021                           61.0    Yes    No
# 4       18/05/2021     28/06/2021                          240.0    Yes    No
# ...            ...            ...                            ...    ...   ...
# 10015          NaN            NaN                            NaN    NaN   NaN
# 10016          NaN            NaN                            NaN    NaN   NaN
# 10017          NaN            NaN                            NaN    NaN   NaN
# 10018          NaN            NaN                            NaN    NaN   NaN
# 10019          NaN            NaN                            NaN    NaN   NaN
#
#       PREDICTED_DELIVERED_DATE  vehicle_no       vehicleType Driver_Name  \
# 0                   30/06/2021    KA590408  Mahindra LCV 1MT      RAMESH
# 1                   30/06/2021  TN30BC5917  Mahindra LCV 1MT      RAMESH
# 2                   24/05/2021  TN22AR2748  Mahindra LCV 1MT        GIRI
# 3                   29/06/2021  TN28AQ0781  Mahindra LCV 1MT        RAVI
# 4                   28/06/2021   TN68F1722  Mahindra LCV 1MT       TAMIL
# ...                        ...         ...               ...         ...
# 10015                      NaN         NaN               NaN         NaN
# 10016                      NaN         NaN               NaN         NaN
# 10017                      NaN         NaN               NaN         NaN
# 10018                      NaN         NaN               NaN         NaN
# 10019                      NaN         NaN               NaN         NaN
#
#        Driver_MobileNo  ... order_id_date  vehicle_no  customer_id  \
# 0         7.082423e+09  ...    15/05/2021    KA590408  72c00ba8bc7
# 1         7.082423e+09  ...    15/05/2021  TN30BC5917  b18a428ac77
# 2         7.082423e+09  ...      8/4/2021  TN22AR2748  2fdd0374a03
# 3         7.082423e+09  ...    16/05/2021  TN28AQ0781  dc6358b12c3
# 4         7.082423e+09  ...    15/05/2021   TN68F1722  c12e35b23ad
# ...                ...  ...           ...         ...          ...
# 10015              NaN  ...      2/5/2021   AP13X6686          NaN
# 10016              NaN  ...      3/5/2021   AP13X6687          NaN
# 10017              NaN  ...      4/5/2021   AP13X6688          NaN
# 10018              NaN  ...      5/5/2021   AP13X6689          NaN
# 10019              NaN  ...      6/5/2021   AP13X6690          NaN
#
#       PLACE_OF_SENDERS PLACE_OF_RECEIVERS 1 PLACE_OF_RECEIVERS 2  \
# 0             New York  Chincoteague Island           Fort Wayne
# 1             San Jose               Exmore               Newark
# 2           Birmingham        Lawrenceville            Arlington
# 3             San Jose           Midlothian           Fort Wayne
# 4               Boston       Virginia Beach          Baton Rouge
# ...                ...                  ...                  ...
# 10015         San Jose                  NaN                  NaN
# 10016         San Jose                  NaN                  NaN
# 10017         San Jose         Johnson City                  NaN
# 10018         San Jose         Johnson City            Charlotte
# 10019         San Jose         Johnson City            Charlotte
#
#       PLACE_OF_RECEIVERS 3 Unnamed: 8 Customer Fname Customer Lname
# 0                     Mesa        NaN           Mary          Smith
# 1                  Garland        NaN         Hannah          Smith
# 2               Scottsdale        NaN           Mary         Nelson
# 3                    Plano        NaN         Austin         Sexton
# 4                  Garland        NaN        Michael          Scott
# ...                    ...        ...            ...            ...
# 10015              Garland        NaN        Russell        Cameron
# 10016              Garland        NaN           Mary          Blake
# 10017              Garland        NaN          Laura          Smith
# 10018                  NaN        NaN           Mary          Smith
# 10019              Garland        NaN           Mary          Cohen
#
# [10020 rows x 26 columns]

# %%
df3=df3.drop('First_name', axis=1)
df3
# Out:
#       SENDERS_DATE RECEIVERS_DATE  TRANSPORTATION_DISTANCE_IN_KM ontime delay  \
# 0       18/05/2021     28/06/2021                          320.0     No   Yes
# 1       18/05/2021     28/06/2021                          103.0    Yes    No
# 2        11/4/2021     22/05/2021                          300.0    Yes    No
# 3       19/05/2021     29/06/2021                           61.0    Yes    No
# 4       18/05/2021     28/06/2021                          240.0    Yes    No
# ...            ...            ...                            ...    ...   ...
# 10015          NaN            NaN                            NaN    NaN   NaN
# 10016          NaN            NaN                            NaN    NaN   NaN
# 10017          NaN            NaN                            NaN    NaN   NaN
# 10018          NaN            NaN                            NaN    NaN   NaN
# 10019          NaN            NaN                            NaN    NaN   NaN
#
#       PREDICTED_DELIVERED_DATE  vehicle_no       vehicleType Driver_Name  \
# 0                   30/06/2021    KA590408  Mahindra LCV 1MT      RAMESH
# 1                   30/06/2021  TN30BC5917  Mahindra LCV 1MT      RAMESH
# 2                   24/05/2021  TN22AR2748  Mahindra LCV 1MT        GIRI
# 3                   29/06/2021  TN28AQ0781  Mahindra LCV 1MT        RAVI
# 4                   28/06/2021   TN68F1722  Mahindra LCV 1MT       TAMIL
# ...                        ...         ...               ...         ...
# 10015                      NaN         NaN               NaN         NaN
# 10016                      NaN         NaN               NaN         NaN
# 10017                      NaN         NaN               NaN         NaN
# 10018                      NaN         NaN               NaN         NaN
# 10019                      NaN         NaN               NaN         NaN
#
#        Driver_MobileNo  ... order_id_date  vehicle_no  customer_id  \
# 0         7.082423e+09  ...    15/05/2021    KA590408  72c00ba8bc7
# 1         7.082423e+09  ...    15/05/2021  TN30BC5917  b18a428ac77
# 2         7.082423e+09  ...      8/4/2021  TN22AR2748  2fdd0374a03
# 3         7.082423e+09  ...    16/05/2021  TN28AQ0781  dc6358b12c3
# 4         7.082423e+09  ...    15/05/2021   TN68F1722  c12e35b23ad
# ...                ...  ...           ...         ...          ...
# 10015              NaN  ...      2/5/2021   AP13X6686          NaN
# 10016              NaN  ...      3/5/2021   AP13X6687          NaN
# 10017              NaN  ...      4/5/2021   AP13X6688          NaN
# 10018              NaN  ...      5/5/2021   AP13X6689          NaN
# 10019              NaN  ...      6/5/2021   AP13X6690          NaN
#
#       PLACE_OF_SENDERS PLACE_OF_RECEIVERS 1 PLACE_OF_RECEIVERS 2  \
# 0             New York  Chincoteague Island           Fort Wayne
# 1             San Jose               Exmore               Newark
# 2           Birmingham        Lawrenceville            Arlington
# 3             San Jose           Midlothian           Fort Wayne
# 4               Boston       Virginia Beach          Baton Rouge
# ...                ...                  ...                  ...
# 10015         San Jose                  NaN                  NaN
# 10016         San Jose                  NaN                  NaN
# 10017         San Jose         Johnson City                  NaN
# 10018         San Jose         Johnson City            Charlotte
# 10019         San Jose         Johnson City            Charlotte
#
#       PLACE_OF_RECEIVERS 3 Unnamed: 8 Customer Fname Customer Lname
# 0                     Mesa        NaN           Mary          Smith
# 1                  Garland        NaN         Hannah          Smith
# 2               Scottsdale        NaN           Mary         Nelson
# 3                    Plano        NaN         Austin         Sexton
# 4                  Garland        NaN        Michael          Scott
# ...                    ...        ...            ...            ...
# 10015              Garland        NaN        Russell        Cameron
# 10016              Garland        NaN           Mary          Blake
# 10017              Garland        NaN          Laura          Smith
# 10018                  NaN        NaN           Mary          Smith
# 10019              Garland        NaN           Mary          Cohen
#
# [10020 rows x 25 columns]
